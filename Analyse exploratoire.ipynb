# %%
# %matplotlib inline

# %%
import pandas

# %%
data = pandas.read_csv('C:\\Users\\Alexis\\Downloads\\engsoccerdata-master\\data-raw\\france.csv', index_col=0, parse_dates=[1], infer_datetime_format=True)

# %%
data.head(6)
# Out:
#         Date  Season                            home                  visitor  \
# 1 1933-07-01    1932                  CA Paris (alt)                AS Cannes
# 2 1933-07-01    1932                  SC Fives Lille                  FC Sete
# 3 1933-07-01    1932             Olympique Marseille                 OGC Nice
# 4 1933-07-01    1932                        SC Nimes  Olympique Lillois Lille
# 5 1933-07-01    1932                      FC Antibes             Stade Rennes
# 6 1933-07-01    1932  Stade Olympique Montpellierain    Racing Club de France
#
#     FT  hgoal  vgoal  division  tier  totgoal  goaldif result
# 1  5-1      5      1         1     1        6        4      H
# 2  4-2      4      2         1     1        6        2      H
# 3  4-0      4      0         1     1        4        4      H
# 4  3-3      3      3         1     1        6        0      D
# 5  1-1      1      1         1     1        2        0      D
# ...

# %%
data.groupby(by=data.Season).mean()
# Out:
#            hgoal     vgoal  division  tier   totgoal   goaldif
# Season
# 1932    2.818681  1.686813       1.0   1.0  4.505495  1.131868
# 1933    2.458333  1.458333       1.0   1.0  3.916667  1.000000
# 1934    2.350000  1.454167       1.0   1.0  3.804167  0.895833
# 1935    2.275000  1.350000       1.0   1.0  3.625000  0.925000
# 1936    1.991667  1.312500       1.0   1.0  3.304167  0.679167
# 1938    1.970833  1.220833       1.0   1.0  3.191667  0.750000
# 1945    2.153595  1.382353       1.0   1.0  3.535948  0.771242
# 1946    2.235294  1.305882       1.0   1.0  3.541176  0.929412
# 1947    2.277778  1.401961       1.0   1.0  3.679739  0.875817
# 1948    2.395425  1.323529       1.0   1.0  3.718954  1.071895
# 1949    2.186275  1.349673       1.0   1.0  3.535948  0.836601
# 1950    2.032680  1.287582       1.0   1.0  3.320261  0.745098
# 1951    2.173203  1.261438       1.0   1.0  3.434641  0.911765
# 1952    1.996732  1.147059       1.0   1.0  3.143791  0.849673
# ...

# %%
data.groupby(by=data.Season)["hgoal","vgoal","totgoal","goaldif"].mean().plot()

# %%
import seaborn as sns

[sns.distplot(data[data.Season == i].totgoal) for i in (1932, 2014)]
# Out:
# C:\Users\Alexis\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# ...

# %%
data[data.Season == 1932].totgoal.mean()
# Out:
# 4.5054945054945055

# %%
data[data.Season == 2014].totgoal.mean()
# Out:
# 2.4921052631578946

# %%
data.home.unique()
# Out:
# array(['CA Paris (alt)', 'SC Fives Lille', 'Olympique Marseille',
#        'SC Nimes', 'FC Antibes', 'Stade Olympique Montpellierain',
#        'Excelsior Roubaix', 'FC Sete', 'OGC Nice', 'Racing Club de France',
#        'AS Cannes', 'Stade Rennes', 'FC Sochaux',
#        'Olympique Lillois Lille', 'FC Mulhouse', 'Olympique Ales',
#        'Red Star Olympique', 'RC Strasbourg', 'FC Metz',
#        'US Valenciennes-Anzin', 'RC Roubaix', 'FC Rouen', 'RC Lens',
#        'Le Havre AC', 'AS Saint-Etienne', 'Lille OSC',
#        'Girondins Bordeaux', 'Stade Reims', 'Olympique Lyon',
#        'Red Star Olympique Audonien', 'Toulouse FC', 'Stade Francais',
#        'AS Nancy', 'AS Cannes-Grasse', 'Stade Red Star', 'SR Colmar',
#        'Nimes Olympique', 'Stade Francais FC', 'AS Monaco',
#        'AS Troyes-Savinienne', 'UA Sedan-Torcy', 'Angers SCO',
#        'AS Beziers', 'Limoges FC', 'Sporting Toulon Var',
#        'Grenoble Foot 38', 'FC Nantes', 'Red Star FC', 'CS Sedan',
# ...

# %%
len(data.home.unique())
# Out:
# 82

# %%
data.hgoal.mean()
# Out:
# 1.7501441919483216

# %%
data.vgoal.mean()
# Out:
# 1.0406044526473641

# %%
data["Vainqueur"] = data.
